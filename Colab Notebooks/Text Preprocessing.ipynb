# %%
import tensorflow as tf

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
device_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c379a85838a9> in <module>()
# ----> 1 device_name
#
# NameError: name 'device_name' is not defined

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sentences = [
    'I love eggs and chicken',
    'I love marijuana and munchies',
    'I hate tomato'
]

# %%
max_vocab_size = 20000
tokenizer = Tokenizer(num_words=max_vocab_size)
tokenizer.fit_on_texts(sentences)
sequences = tokenizer.texts_to_sequences(sentences)

# %%
print(sequences)
# Out:
# [[1, 2, 4, 3, 5], [1, 2, 6, 3, 7], [1, 8, 9]]

# %%
tokenizer.index_word
# Out:
# {1: 'i',
#  2: 'love',
#  3: 'and',
#  4: 'eggs',
#  5: 'chicken',
#  6: 'marijuana',
#  7: 'munchies',
#  8: 'hate',
#  9: 'tomato'}

# %%
data = pad_sequences(sequences, maxlen=5)
data
# Out:
# array([[1, 2, 4, 3, 5],
#        [1, 2, 6, 3, 7],
#        [0, 0, 1, 8, 9]], dtype=int32)

# %%
data =  pad_sequences(sequences,maxlen=5,padding='post')
data
# Out:
# array([[1, 2, 4, 3, 5],
#        [1, 2, 6, 3, 7],
#        [1, 8, 9, 0, 0]], dtype=int32)

# %%
data = pad_sequences(sequences,maxlen=4,truncating='pre')
data
# Out:
# array([[2, 4, 3, 5],
#        [2, 6, 3, 7],
#        [0, 1, 8, 9]], dtype=int32)
